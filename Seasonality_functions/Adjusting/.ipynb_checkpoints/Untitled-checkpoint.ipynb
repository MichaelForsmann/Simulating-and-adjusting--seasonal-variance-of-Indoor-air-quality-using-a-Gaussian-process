# %%
import scipy as sp
import torch 
from scipy import integrate
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from bokeh.plotting import figure, show
import pandas as pd
from bokeh.io import curdoc,output_notebook,export_png
from bokeh.layouts import column,gridplot
#from print_versions import print_versions
from sklearn.metrics import r2_score
from seaborn import clustermap
from bokeh.models import Band, ColumnDataSource
import pandas as pd
TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,examine,help"

# %%
data=pd.read_excel(r"../../Data_and_Preprocessing/before_season_correction.xlsx")

# %%
data_pm25=pd.read_excel(r"../../Data_and_Preprocessing/pm25_BC_corrected.xlsx")

# %%
gpr_pm25=torch.load("../models/pm25_seasonality",weights_only=False,map_location='cuda')
gpr_bc=torch.load("../models/seasonality_BC",weights_only=False,map_location='cuda')
gpr_no2=torch.load("../models/no2_seasonality",weights_only=False,map_location='cuda')
gpr_nox=torch.load("../models/nox_seasonality",weights_only=False,map_location='cuda')
gpr_form=torch.load("../models/form_seasonality",weights_only=False,map_location='cuda')
gpr_acetald=torch.load("../models/acetald_seasonality",weights_only=False,map_location='cuda')
gpr_acetone=torch.load("../models/acetone_seasonality",weights_only=False,map_location='cuda')

# %%
data.loc[:,"theta"]=data.corrected_week/data.corrected_week.max()*2*np.pi
data.loc[:,"cos_theta"]=np.cos(data.corrected_week/data.corrected_week.max()*2*np.pi)
data.loc[:,"sin_theta"]=np.sin(data.corrected_week/data.corrected_week.max()*2*np.pi)

# %%
data.corrected_week
# Out:
# 0       2.714286
# 1      32.571429
# 2      32.857143
# 3      25.571429
# 4      23.857143
#          ...
# 960     5.571429
# 961    49.714286
# 962    24.142857
# 963    31.142857
# 964    27.428571
# Name: corrected_week, Length: 965, dtype: float64

# %%
def scale_season(data,model):
    X=[]
    for i in data.corrected_week: 
        x=np.linspace(i-26,i,500)
        x1=np.where(x<0,52.5+x,x)
        theta=x1*2*np.pi/52.5
        sin=np.sin(theta)
        cos=np.sin(theta)
        periodic_data=pd.DataFrame(np.array([cos,sin]).T,columns=["x_cos","x_sin"])
        linmod=torch.from_numpy(periodic_data.values.astype("float64")).to(device)
        y=model(linmod)[0].cpu().detach().numpy()
        X.append(integrate.simpson(y)/(len(y)*y[-1]))
    return X

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
data
# Out:
#      Unnamed: 0.1  cpnr  Unnamed: 0  maalnr  constrution_year   Area  \
# 0               0    50       109.0     1.0            1939.0  132.0
# 1               1    50       110.0     2.0            1939.0  132.0
# 2               2    50       111.0     3.0            1939.0  132.0
# 3               3   240       587.0     1.0            1900.0  114.8
# 4               4   240       589.0     3.0            1949.0  141.0
# ..            ...   ...         ...     ...               ...    ...
# 960           402    24        44.0     3.0            1905.0  194.0
# 961           403   124       294.0     1.0            1998.0  115.0
# 962           404   124       296.0     3.0            1998.0  115.0
# 963           405   257       621.0     1.0            1996.0  110.0
# 964           406   257       623.0     3.0            1996.0  110.0
#
#      floor_level  powerplant     road  motorway  ...  label  Total_VOCs  \
# ...

# %%
data_pm25["pm_scale"]=scale_season(data_pm25,gpr_pm25)
data_pm25["bc_scale"]=scale_season(data_pm25,gpr_bc)
data["no2_scale"]=scale_season(data,gpr_no2)
data["nox_scale"]=scale_season(data,gpr_nox)
data["form_scale"]=scale_season(data,gpr_form)
data["acetald_scale"]=scale_season(data,gpr_acetald)
data["acetone_scale"]=scale_season(data,gpr_acetone)

# %%
data=data.set_index("cpnr")

# %%
data_count3=data.loc[data.index.value_counts()==3]
data_count3_1=data_count3.loc[data_count3.maalnr==1,:]
data_count3_2=data_count3.loc[data_count3.maalnr==2,:]
data_count3_3=data_count3.loc[data_count3.maalnr==3,:]
data_count3_3=data_count3_3.groupby(data_count3_3.index).mean()

# %%
sns.clustermap(data.loc[:,['no2_scale', 'nox_scale', 'form_scale', 'acetald_scale',
       'acetone_scale']].corr(),annot=True)

# %%
data_pm25["pm25_season"]=data_pm25.pm25_Gaussion*data_pm25.pm_scale
data_pm25["bc_season"]=data_pm25.BC_Gaussion*data_pm25.bc_scale
data["no2_season"]=data.no2*data.no2_scale
data["nox_season"]=data.nox*data.nox_scale
data["form_season"]=data.formaldehyd*data.form_scale
data["acetald_season"]=data.acetald*data.acetald_scale
data["acetone_season"]=data.acetone_scale*data.acetone

# %%
fig,ax=plt.subplots(2,3,figsize=(15,10))
ax[0,0].hist(data["no2_season"],bins=20,density=True)
ax[0,0].hist(data["no2"],bins=20,density=True,alpha=0.5)
ax[0,1].hist(data["nox_season"],bins=20,density=True)
ax[0,1].hist(data["nox"],bins=20,density=True,alpha=0.5)
ax[0,2].hist(data["form_season"],bins=20,density=True)
ax[0,2].hist(data["formaldehyd"],bins=20,density=True,alpha=0.5)
ax[1,0].hist(data["acetald_season"],bins=20,density=True)
ax[1,0].hist(data["acetald"],bins=20,density=True,alpha=0.5)
ax[1,1].hist(data["acetone_season"],bins=20,density=True)
ax[1,1].hist(data["acetone"],bins=20,density=True,alpha=0.5)
# Out:
# (array([0.08884816, 0.03640608, 0.02773796, 0.01950326, 0.01040174,
#         0.00585098, 0.00303384, 0.00151692, 0.00151692, 0.00151692,
#         0.00130022, 0.0002167 , 0.0002167 , 0.00043341, 0.00043341,
#         0.        , 0.0002167 , 0.00043341, 0.        , 0.0002167 ]),
#  array([-9.19500448e-05,  5.00491265e+00,  1.00099172e+01,  1.50149218e+01,
#          2.00199264e+01,  2.50249310e+01,  3.00299356e+01,  3.50349402e+01,
#          4.00399448e+01,  4.50449494e+01,  5.00499540e+01,  5.50549586e+01,
#          6.00599632e+01,  6.50649678e+01,  7.00699724e+01,  7.50749770e+01,
#          8.00799816e+01,  8.50849862e+01,  9.00899908e+01,  9.50949954e+01,
#          1.00100000e+02]),
#  <BarContainer object of 20 artists>)

# %%
fig=sns.clustermap(data.corr().loc[['constrution_year',
       'Area', 'floor_level', 'powerplant', 'road', 'motorway', 'forest',
       'coastline', 'airport', 'farmland', 'industrial', 'carpet',
       'cookerhood', 'passive', 'gastove', 'fireplace'],["no2_season","nox_season","form_season","acetald_season","acetone_season",'no2', 'nox',
       'formaldehyd', 'acetald', 'acetone']],annot=True)
fig = fig.fig
fig.savefig("sources_particles.png")

# %%
fig=sns.clustermap(data_pm25.corr().loc[['constrution_year',
       'Area', 'floor_level', 'powerplant', 'road', 'motorway', 'forest',
       'coastline', 'airport', 'farmland', 'industrial', 'carpet',
       'cookerhood', 'passive', 'gastove', 'fireplace'],["sv_final","pm_final","bc_season","pm25_season","pm25_Gaussion","BC_Gaussion"]],annot=True)
fig = fig.fig
fig.savefig("sources_particles_bc_pm.png")

# %%
data
# Out:
#       Unnamed: 0.1  Unnamed: 0  maalnr  constrution_year   Area  floor_level  \
# cpnr
# 50               0       109.0     1.0            1939.0  132.0          0.0
# 50               1       110.0     2.0            1939.0  132.0          0.0
# 50               2       111.0     3.0            1939.0  132.0          0.0
# 240              3       587.0     1.0            1900.0  114.8          1.0
# 240              4       589.0     3.0            1949.0  141.0          0.0
# ...            ...         ...     ...               ...    ...          ...
# 24             402        44.0     3.0            1905.0  194.0          0.0
# 124            403       294.0     1.0            1998.0  115.0          0.0
# 124            404       296.0     3.0            1998.0  115.0          0.0
# 257            405       621.0     1.0            1996.0  110.0          0.0
# 257            406       623.0     3.0            1996.0  110.0          0.0
#
# ...

# %%
data_chemicals=data.loc[:,['cpnr','visit','no2_season', 'nox_season','form_season',
       'acetald_season', 'acetone_season','no2', 'nox',
       'formaldehyd', 'acetald', 'acetone']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 data_chemicals=data.loc[:,['cpnr','visit','no2_season', 'nox_season','form_season',
#       2        'acetald_season', 'acetone_season','no2', 'nox',
#       3        'formaldehyd', 'acetald', 'acetone']]
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
# ...

# %%
data_chemicals_1=data_chemicals.loc[data_chemicals.visit==1].set_index("cpnr").drop(['visit'],axis=1)
data_chemicals_2=data_chemicals.loc[data_chemicals.visit==2].set_index("cpnr").drop(['visit'],axis=1)
data_chemicals_3=data_chemicals.loc[data_chemicals.visit==3].set_index("cpnr").drop(['visit'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 data_chemicals_1=data_chemicals.loc[data_chemicals.visit==1].set_index("cpnr").drop(['visit'],axis=1)
#       2 data_chemicals_2=data_chemicals.loc[data_chemicals.visit==2].set_index("cpnr").drop(['visit'],axis=1)
#       3 data_chemicals_3=data_chemicals.loc[data_chemicals.visit==3].set_index("cpnr").drop(['visit'],axis=1)
#
# NameError: name 'data_chemicals' is not defined

# %%
data_chemicals_1=data_chemicals_1.rename(columns=dict(zip(data_chemicals_1.columns,data_chemicals_1.columns+"_m6")))
data_chemicals_2=data_chemicals_2.rename(columns=dict(zip(data_chemicals_2.columns,data_chemicals_2.columns+"_m12")))
data_chemicals_3=data_chemicals_3.rename(columns=dict(zip(data_chemicals_3.columns,data_chemicals_3.columns+"_m18")))
data_all_no2=pd.concat([data_chemicals_1,data_chemicals_2,data_chemicals_3],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 data_chemicals_1=data_chemicals_1.rename(columns=dict(zip(data_chemicals_1.columns,data_chemicals_1.columns+"_m6")))
#       2 data_chemicals_2=data_chemicals_2.rename(columns=dict(zip(data_chemicals_2.columns,data_chemicals_2.columns+"_m12")))
#       3 data_chemicals_3=data_chemicals_3.rename(columns=dict(zip(data_chemicals_3.columns,data_chemicals_3.columns+"_m18")))
#
# NameError: name 'data_chemicals_1' is not defined

# %%
data_all_no2.index.name="bnr"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 data_all_no2.index.name="bnr"
#
# NameError: name 'data_all_no2' is not defined

# %%
data_pm25
# Out:
#       Unnamed: 0  bnr  flow  pm_final  sv_final  maalnr  constrution_year  \
# 0              0    1  4.07     3.748     0.162       1            1979.0
# 1              1    1  3.75    13.851     3.060       2            1979.0
# 2              2    1  4.22     6.938     0.343       3            1979.0
# 3              3    3  3.78    83.668     0.962       1            1924.0
# 4              4    3  3.74    59.950     1.790       2            1924.0
# ...          ...  ...   ...       ...       ...     ...               ...
# 1115        1115  450  3.96    13.040     0.562       3            1968.0
# 1116        1116  451  3.88    23.291     1.544       1            1987.0
# 1117        1117  452  3.92    18.355     1.033       1            1925.0
# 1118        1118  452  4.05    19.422     2.665       2            1925.0
# 1119        1119  452  4.10    20.405     1.082       3            1925.0
#
#        Area  floor_level  powerplant  ...    BC_exp      BC_log  \
# ...

# %%
data_pm=data_pm25.loc[:,['maalnr','pm_final','sv_final','bnr','pm25_season',
       'bc_season','pm25_Gaussion','bc_Gaussion']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[327], line 1
# ----> 1 data_pm=data_pm25.loc[:,['maalnr','pm_final','sv_final','bnr','pm25_season',
#       2        'bc_season','pm25_Gaussion','bc_Gaussion']]
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# ...

# %%
data_pm_1=data_pm.loc[data_pm.maalnr==1].set_index("bnr").drop(['maalnr'],axis=1)
data_pm_2=data_pm.loc[data_pm.maalnr==2].set_index("bnr").drop(['maalnr'],axis=1)
data_pm_3=data_pm.loc[data_pm.maalnr==3].set_index("bnr").drop(['maalnr'],axis=1)

# %%
data_pm_1=data_pm_1.rename(columns=dict(zip(data_pm_1.columns,data_pm_1.columns+"_m6")))
data_pm_2=data_pm_2.rename(columns=dict(zip(data_pm_2.columns,data_pm_2.columns+"_m12")))
data_pm_3=data_pm_3.rename(columns=dict(zip(data_pm_3.columns,data_pm_3.columns+"_m18")))
data_all=pd.concat([data_pm_1,data_pm_2,data_pm_3],axis=1)

# %%
fulldata.columns
# Out:
# Index(['pm_final_m6', 'sv_final_m6', 'pm25_season_m6', 'bc_season_m6',
#        'pm25_Gaussion_m6', 'BC_Gaussion_m6', 'pm_final_m12', 'sv_final_m12',
#        'pm25_season_m12', 'bc_season_m12', 'pm25_Gaussion_m12',
#        'BC_Gaussion_m12', 'pm_final_m18', 'sv_final_m18', 'pm25_season_m18',
#        'bc_season_m18', 'pm25_Gaussion_m18', 'BC_Gaussion_m18',
#        'no2_season_m6', 'nox_season_m6', 'form_season_m6', 'acetald_season_m6',
#        'acetone_season_m6', 'no2_m6', 'nox_m6', 'formaldehyd_m6', 'acetald_m6',
#        'acetone_m6', 'no2_season_m12', 'nox_season_m12', 'form_season_m12',
#        'acetald_season_m12', 'acetone_season_m12', 'no2_m12', 'nox_m12',
#        'formaldehyd_m12', 'acetald_m12', 'acetone_m12', 'no2_season_m18',
#        'nox_season_m18', 'form_season_m18', 'acetald_season_m18',
#        'acetone_season_m18', 'no2_m18', 'nox_m18', 'formaldehyd_m18',
#        'acetald_m18', 'acetone_m18'],
#       dtype='object')

# %%
sns.clustermap(fulldata.corr().loc[['BC_Gaussion_m6','BC_Gaussion_m12','BC_Gaussion_m18','nox_m6','nox_m12','nox_m18','no2_m6','no2_m12','no2_m18'],['BC_Gaussion_m6','BC_Gaussion_m12','BC_Gaussion_m18','nox_m6','nox_m12','nox_m18','no2_m6','no2_m12','no2_m18']],figsize=(10,10), annot=True)

# %%
sns.clustermap(fulldata.corr().loc[['bc_season_m6','bc_season_m12','bc_season_m18','nox_season_m6','nox_season_m12','nox_season_m18','no2_season_m6','no2_season_m12','no2_season_m18'],['bc_season_m6','bc_season_m12','bc_season_m18','nox_season_m6','nox_season_m12','nox_season_m18','no2_season_m6','no2_season_m12','no2_season_m18']],figsize=(10,10), annot=True)

# %%
fulldata.loc[:,["pm25_season_m6","pm25_season_m12","pm25_season_m18"]].mean(axis=1).hist(bins=20,range=[-0.1,100])
# Out:
# <Axes: >

# %%
fulldata.loc[:,["pm25_Gaussion_m6","pm25_Gaussion_m12","pm25_Gaussion_m18"]].mean(axis=1).hist(bins=20,range=[-0.1,100])
# Out:
# <Axes: >

# %%
fulldata.loc[:,["bc_season_m6","bc_season_m12","bc_season_m18"]].std(axis=1).hist()
# Out:
# <Axes: >

# %%
fulldata.loc[:,["bc_season_m6","bc_season_m12","bc_season_m18"]].std(axis=1).mean()
# Out:
# 0.37475525225755296

# %%
fulldata.loc[:,["sv_final_m6","sv_final_m12","sv_final_m18"]].std(axis=1).mean()
# Out:
# 0.4359531719272928

# %%
fulldata.loc[:,["pm25_season_m6","pm25_season_m12","pm25_season_m18"]].std(axis=1).mean()
# Out:
# 7.395458590155677

# %%
fulldata.loc[:,["pm25_Gaussion_m6","pm25_Gaussion_m12","pm25_Gaussion_m18"]].std(axis=1).mean()
# Out:
# 7.902535736074632

# %%
fulldata=pd.concat([data_all,data_all_no2],axis=1)

# %%
fulldata.to_excel("indoor_air_corrcted_season.xlsx")

# %%
sns.clustermap(fulldata.corr(),figsize=(30,30))
