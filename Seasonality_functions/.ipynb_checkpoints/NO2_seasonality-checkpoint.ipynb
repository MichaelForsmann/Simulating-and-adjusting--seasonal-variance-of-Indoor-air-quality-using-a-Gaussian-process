# %%
import pandas as pd
import arviz as az
from Functions import *

# %%
data=pd.read_excel(r"../Data_and_Preprocessing/before_season_correction.xlsx")
device='cuda'

# %%
train=data.loc[data.label==0,:]

# %%
train=make_periodic(train,"corrected_week",device )
# Out:
# /home/michaelf/Seasonality_pyro_rewrite/Seasonality_functions/Functions.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:,"theta"]=data.loc[:,variable]/data.loc[:,variable].max()*2*np.pi
# /home/michaelf/Seasonality_pyro_rewrite/Seasonality_functions/Functions.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:,"cos_theta"]=np.cos(data.loc[:,"theta"])
# /home/michaelf/Seasonality_pyro_rewrite/Seasonality_functions/Functions.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:,"sin_theta"]=np.sin(data.loc[:,"theta"])

# %%
X_no2,y_no2=make_Xy(train,["cos_theta","sin_theta"],"no2",device) 
nuts_kernel_no2,gpr_no2=model(X_no2,y_no2,device) 
pyro_data,gpr_no2=train_model(X_no2,nuts_kernel_no2,gpr_no2,device) 
torch.save(gpr_no2, "models/no2_seasonality");
# Out:
# Sample: 100%|██████████████████████████████████████| 14000/14000 [11:21, 20.54it/s, step size=7.77e-01, acc. prob=0.907]
# /data/michaelf/miniconda3/lib/python3.10/site-packages/arviz/data/io_pyro.py:158: UserWarning: Could not get vectorized trace, log_likelihood group will be omitted. Check your model vectorization or set log_likelihood=False
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 4
#       2 nuts_kernel_no2,gpr_no2=model(X_no2,y_no2,device)
#       3 pyro_data,gpr_no2=train_model(X_no2,nuts_kernel_no2,gpr_no2,device)
# ----> 4 torch.save(gpr_no2, "../models/no2_seasonality");
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/torch/serialization.py:849, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     846 _check_save_filelike(f)
#     848 if _use_new_zipfile_serialization:
# --> 849     with _open_zipfile_writer(f) as opened_zipfile:
#     850         _save(
#     851             obj,
#     852             opened_zipfile,
#    (...)
#     855             _disable_byteorder_record,
#     856         )
#     857         return
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/torch/serialization.py:716, in _open_zipfile_writer(name_or_buffer)
#     714 else:
#     715     container = _open_zipfile_writer_buffer
# --> 716 return container(name_or_buffer)
#
# File /data/michaelf/miniconda3/lib/python3.10/site-packages/torch/serialization.py:687, in _open_zipfile_writer_file.__init__(self, name)
#     685     super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     686 else:
# --> 687     super().__init__(torch._C.PyTorchFileWriter(self.name))
#
# RuntimeError: Parent directory ../models does not exist.

# %%
X_nox,y_nox=make_Xy(train,["cos_theta","sin_theta"],"nox",device) 
nuts_kernel,gpr_nox=model(X_nox,y_nox,device) 
pyro_data,gpr_nox=train_model(X_nox,nuts_kernel,gpr_nox,device) 
torch.save(gpr_nox, "models/nox_seasonality");
# Out:
# Sample: 100%|██████████████████████████████████████| 14000/14000 [13:02, 17.89it/s, step size=7.61e-01, acc. prob=0.921]
# /data/michaelf/miniconda3/lib/python3.10/site-packages/arviz/data/io_pyro.py:158: UserWarning: Could not get vectorized trace, log_likelihood group will be omitted. Check your model vectorization or set log_likelihood=False
#   warnings.warn(
