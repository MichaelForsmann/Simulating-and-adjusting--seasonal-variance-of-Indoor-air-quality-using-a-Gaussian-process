# %%
import pandas as pd
import arviz as az
from Functions import *

# %%
data=pd.read_excel(r"../Data_and_Preprocessing/before_season_correction.xlsx")

# %%
train=data.loc[data.label==0,:]

# %%
device="cuda"

# %%
train=make_periodic(train,"corrected_week",device)
# Out:
# /home/michaelf/Seasonality_pyro_rewrite/Seasonality_functions/Functions.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:,"theta"]=data.loc[:,variable]/data.loc[:,variable].max()*2*np.pi
# /home/michaelf/Seasonality_pyro_rewrite/Seasonality_functions/Functions.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:,"cos_theta"]=np.cos(data.loc[:,"theta"])
# /home/michaelf/Seasonality_pyro_rewrite/Seasonality_functions/Functions.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[:,"sin_theta"]=np.sin(data.loc[:,"theta"])

# %%
X_formaldehyd,y_formaldehyd=make_Xy(train,["cos_theta","sin_theta"],"formaldehyd",device) 
nuts_kernel_formaldehyd,gpr_formaldehyd=model(X_formaldehyd,y_formaldehyd,device) 
pyro_form,gpr_formaldehyd=train_model(X_formaldehyd,nuts_kernel_formaldehyd,gpr_formaldehyd,device) 
torch.save(gpr_formaldehyd,"models/formaldehyd_seasonality");
# Out:
# Sample: 100%|██████████████████████████████████████| 14000/14000 [11:09, 20.92it/s, step size=8.72e-01, acc. prob=0.870]
# /data/michaelf/miniconda3/lib/python3.10/site-packages/arviz/data/io_pyro.py:158: UserWarning: Could not get vectorized trace, log_likelihood group will be omitted. Check your model vectorization or set log_likelihood=False
#   warnings.warn(

# %%
X_acetald,y_acetald=make_Xy(train,["cos_theta","sin_theta"],"acetald",device) 
nuts_kernel_acetald,gpr_acetald=model(X_acetald,y_acetald,device) 
pyro_acetald,gpr_acetald=train_model(X_acetald,nuts_kernel_acetald,gpr_acetald,device) 
torch.save(gpr_acetald,"models/acetald_seasonality");
# Out:
# Sample: 100%|██████████████████████████████████████| 14000/14000 [10:14, 22.78it/s, step size=6.37e-01, acc. prob=0.942]
# /data/michaelf/miniconda3/lib/python3.10/site-packages/arviz/data/io_pyro.py:158: UserWarning: Could not get vectorized trace, log_likelihood group will be omitted. Check your model vectorization or set log_likelihood=False
#   warnings.warn(

# %%
X_acetone,y_acetone=make_Xy(train,["cos_theta","sin_theta"],"acetone",device) 
nuts_kernel_acetone,gpr_acetone=model(X_acetone,y_acetone,device) 
pyro_acetone,gpr_acetone=train_model(X_acetone,nuts_kernel_acetone,gpr_acetone,device) 
torch.save(gpr_acetone,"models/acetone_seasonality");
# Out:
# Sample: 100%|██████████████████████████████████████| 14000/14000 [10:17, 22.66it/s, step size=7.44e-01, acc. prob=0.923]
# /data/michaelf/miniconda3/lib/python3.10/site-packages/arviz/data/io_pyro.py:158: UserWarning: Could not get vectorized trace, log_likelihood group will be omitted. Check your model vectorization or set log_likelihood=False
#   warnings.warn(

# %%
X_vocs,y_vocs=make_Xy(train,["cos_theta","sin_theta"],"Total_VOCs",device) 
nuts_kernel_vocs,gpr_vocs=model(X_vocs,y_vocs,device) 
pyro_vocs,gpr_vocs=train_model(X_vocs,nuts_kernel_vocs,gpr_vocs,device) 
torch.save(gpr_vocs,"models/vocs_seasonality");
# Out:
# Sample: 100%|██████████████████████████████████████| 14000/14000 [07:15, 32.16it/s, step size=6.70e-01, acc. prob=0.939]
# /data/michaelf/miniconda3/lib/python3.10/site-packages/arviz/data/io_pyro.py:158: UserWarning: Could not get vectorized trace, log_likelihood group will be omitted. Check your model vectorization or set log_likelihood=False
#   warnings.warn(
