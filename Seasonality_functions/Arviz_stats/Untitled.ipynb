# %%
import arviz as az

# %%
pyro_data=az.from_json("mcmc_form_seasonality.json")

# %%
az.plot_posterior(pyro_data)
# Out:
# <Axes: title={'center': 'noise'}>

# %%
pyro_data
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> prior
# 	> observed_data
