# %%
import arviz as az
from scipy.optimize import curve_fit
from bokeh.plotting import figure, show,output_file, save
from bokeh.transform import factor_cmap, factor_mark
from bokeh.palettes import Spectral
from bokeh.models import Slope, Div
from bokeh.io import curdoc,output_notebook,export_png
from bokeh.layouts import column,gridplot
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from bokeh.models import Band, ColumnDataSource

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
from Plotting import *

# %%
data=pd.read_excel(r"../../Data_and_Preprocessing/pm25_BC_corrected.xlsx")
train=data.loc[data.label==0,:]
test=data.loc[data.label==1,:]

device="cuda"

# %%
gpr=torch.load("../models/pm25_seasonality",weights_only=False,map_location='cuda')

# %%
gpr_bc=torch.load("../models/seasonality_BC",weights_only=False,map_location='cuda')

# %%
output_notebook()
p=plot("pm25_Gaussion",r"$$PM_{2.5}$$ Seasonality",train,test,gpr)
p1=plot("BC_Gaussion",r"BC Seasonality",train,test,gpr_bc,diffrence=0.3)
p2=plot("pm_final",r"$$PM_{2.5}$$ raw Seasonality",train,test,gpr)
p3=plot("sv_final",r"BC raw Seasonality",train,test,gpr_bc,diffrence=0.3)
grid =  gridplot([[p, p1],[p2,p3]], width=500, height=500);
show(column(grid));
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ec9c394f-5154-485e-82e2-22f447ca49b3">Loading BokehJS ...</span>
#     </div>
#   <div id="f3943056-a915-41e0-a181-02d6c9f0390e" data-root-id="p2006" style="display: contents;"></div>
